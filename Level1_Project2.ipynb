# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv(r"C:\Users\DELL\Downloads\ifood_df.csv")
df1.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df1.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df1.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
df1.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Z_CostContact              1
# Z_Revenue                  1
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# ...

# %%
df1.drop(columns=['Z_CostContact','Z_Revenue'],inplace=True)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df1,y='MntTotal')
plt.ylabel('MntTotal')
plt.show()

# %%
Q1=df1['MntTotal'].quantile(0.25)
Q3=df1['MntTotal'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=df1[(df1['MntTotal']<lower_bound)|(df1['MntTotal']>upper_bound)]
outliers
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 1159  90638.0        0         0       29      1156        120
# 1467  87679.0        0         0       62      1259        172
# 1547  90638.0        0         0       29      1156        120
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 1159              915               94               144            96  ...
# 1467              815               97               148            33  ...
# 1547              915               94               144            96  ...
#
#       marital_Together  marital_Widow  education_2n Cycle  education_Basic  \
# 1159                 0              0                   0                0
# 1467                 1              0                   0                0
# 1547                 0              0                   0                0
#
#       education_Graduation  education_Master  education_PhD  MntTotal  \
# ...

# %%
outliers.describe()
# Out:
#              Income  Kidhome  Teenhome    Recency     MntWines   MntFruits  \
# count      3.000000      3.0       3.0   3.000000     3.000000    3.000000
# mean   89651.666667      0.0       0.0  40.000000  1190.333333  137.333333
# std     1708.379447      0.0       0.0  19.052559    59.467078   30.022214
# min    87679.000000      0.0       0.0  29.000000  1156.000000  120.000000
# 25%    89158.500000      0.0       0.0  29.000000  1156.000000  120.000000
# 50%    90638.000000      0.0       0.0  29.000000  1156.000000  120.000000
# 75%    90638.000000      0.0       0.0  45.500000  1207.500000  146.000000
# max    90638.000000      0.0       0.0  62.000000  1259.000000  172.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# count         3.000000         3.000000          3.000000      3.000000  ...
# mean        881.666667        95.000000        145.333333     75.000000  ...
# ...

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df1,y='Income',color='violet')
plt.ylabel('Income')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df1,x='Income',bins=30,kde=True,color='gray')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df1,x='Age',bins=30,kde=True,color='orchid')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
def marital_status(row):
    if row['marital_Divorced']==1:
        return 'Divorced'
    elif row['marital_Married']==1:
        return 'Married'
    elif row['marital_Single']==1:
        return 'Single'
    elif row['marital_Together']==1:
        return 'Together'
    elif row['marital_Widow']==1:
        return 'Widow'
    else:
        return 'Unknown'
df1['marital']=df1.apply(marital_status,axis=1)

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='marital',y='MntTotal',data=df1,palette='viridis')
# Out:
# <Axes: xlabel='marital', ylabel='MntTotal'>

# %%
cols_demographics = ['Income','Age']
cols_children = ['Kidhome', 'Teenhome']
cols_marital = ['marital_Divorced', 'marital_Married','marital_Single', 'marital_Together', 'marital_Widow']
cols_mnt = ['MntTotal', 'MntRegularProds','MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
cols_communication = ['Complain', 'Response', 'Customer_Days']
cols_campaigns = ['AcceptedCmpOverall', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']
cols_source_of_purchase = ['NumDealsPurchases', 'NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']
cols_education = ['education_2n Cycle', 'education_Basic', 'education_Graduation', 'education_Master', 'education_PhD']

# %%
for i, comm in enumerate(cols_communication):
    plt.figure(figsize=(8,6))
    sns.barplot(x='marital',y=comm,data=df1,palette='viridis')

# %%
plt.figure(figsize=(20,10))
sns.barplot(df1,y='Income',x='Age',color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
df1['Income'].mean()
# Out:
# 51622.0947845805

# %%
sns.boxplot(x='marital',y='Income',data=df1,palette='viridis')
# Out:
# <Axes: xlabel='marital', ylabel='Income'>

# %%
df1['AvgPurchase']=df1['MntTotal']/df1['AcceptedCmpOverall'].replace(0,1)

# %%
df1['PurchaseFrequency']=df1['AcceptedCmpOverall']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
features=df1[['Income','Recency','MntTotal','AvgPurchase','PurchaseFrequency']]

# %%
scaler=StandardScaler()
scaled_features=scaler.fit_transform(features)

# %%
inertia=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,random_state=42)
    df1['Data_obt']=kmeans.fit_predict(scaled_features)
    inertia.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
# Apply KMeans with optimal k (say, k=4)
kmeans = KMeans(n_clusters=4, random_state=42)
df1['Cluster'] = kmeans.fit_predict(scaled_features)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df1, x='Income', y='MntTotal', hue='Cluster', palette='viridis')
plt.title('Customer Segments by Income and Spending')
plt.show()

# %%
# Bar chart of average spending per cluster
df1.groupby('Cluster')['MntTotal'].mean().plot(kind='bar', title='Avg Spending per Cluster')
plt.ylabel('Average Spending')
plt.show()

# %%
segment_summary=df1.groupby('Data_obt')[['Recency','Response','MntTotal']].mean()
segment_summary
# Out:
#             Recency  Response     MntTotal
# Data_obt
# 0         48.593220  0.661017  1560.220339
# 1         25.222689  0.113445   330.882353
# 2         82.917582  0.024725   106.233516
# 3         75.157303  0.162921  1449.556180
# 4         73.512821  0.029915   692.200855
# 5         25.277778  0.119658   946.764957
# 6         15.599327  0.202020    69.228956
# 7         24.765766  0.396396  1585.234234
# 8         49.944805  0.077922    70.435065
# 9         55.983740  0.219512   647.284553
